# %% [markdown]
# # Getting Started with Data-Juicer
#
# Welcome to Data-Juicer! This notebook will guide you through the basics of using Data-Juicer for data processing. We'll cover installation, core concepts, and create your first data processing pipeline.
#
# ## What is Data-Juicer?
#
# Data-Juicer is a one-stop system to process text and multimodal data for and with foundation models (typically LLMs). It provides:
#
# - A rich library of operators for data cleaning, filtering, and transformation
# - Support for text, image, audio, and video data
# - Both single-machine and distributed processing capabilities
# - Easy extensibility with custom operators
#
# ## In this Notebook
#
# 1. Installation and setup
# 2. Core concepts: operators, recipes, and executors
# 3. Your first data processing pipeline
# 4. Basic configuration
# 5. Running a simple processing job

# %% [markdown]
# ## Installation
#
# First, let's install Data-Juicer. If you're in the Data-Juicer playground, this step is already done for you. Otherwise, uncomment and run the appropriate command:

# %%
# Installation Guide: https://modelscope.github.io/data-juicer/en/main/docs/tutorial/Installation.html
# Install from PyPI
# !uv pip install py-data-juicer

# Or install from source
# !pip install git+https://github.com/modelscope/data-juicer

# %% [markdown]
# ## Core Concepts
#
# Data-Juicer is built around several core concepts:
#
# ### Operators
# Operators are the basic building blocks that perform specific data processing tasks. There are several types:
# - **Mapper**: Edits and transforms samples (e.g., text cleaning)
# - **Filter**: Filters out low-quality samples (e.g., language filtering)
# - **Deduplicator**: Detects and removes duplicate samples
# - **Selector**: Selects top samples based on ranking
# - **Grouper**: Group samples to batched samples
# - **Aggregator**: Aggregate for batched samples, such as summary or conclusion
#
# ### Recipes
# Recipes are YAML configuration files that define a sequence of operators to apply to your data.
#
# ### Executors
# Executors run the processing pipeline defined in a recipe. Data-Juicer provides both local and distributed executors.

# %% [markdown]
# ## Your First Data Processing Pipeline
#
# Let's create a simple data processing pipeline. First, we'll create a sample dataset to work with.

# %%
import os
import json

# Create a sample dataset
sample_data = [
    {"text": "Hello world! This is a sample text with good quality."},
    {"text": "hello world! this is a sample text with good quality."},
    {"text": "a text"},
    {"text": "Bonjour le monde! Ceci est un texte d'exemple de bonne qualité."},
    {"text": "Hello world! \tHello world! This is a sample text with good quality. Hello world! This is a sample text with good quality."}
]

# Create data directory if it doesn't exist
os.makedirs('data', exist_ok=True)

# Write sample data to a JSONL file
with open('data/sample_dataset.jsonl', 'w') as f:
    for item in sample_data:
        f.write(json.dumps(item) + '\n')

print("Sample dataset created with", len(sample_data), "samples")
print("First sample:", sample_data[0])
# Out:
# Sample dataset created with 5 samples
# First sample: {'text': 'Hello world! This is a sample text with good quality.'}

# %% [markdown]
# Now let's create a simple recipe that:
# 1. Normalizes whitespace
# 2. Filters by language (English)
# 3. Filters by text length
# 4. Removes duplicates

# %%
recipe_content = """
project_name: 'getting_started_tutorial'
dataset_path: './data/sample_dataset.jsonl'
export_path: './outputs/processed_dataset.jsonl'
np: 1  # Number of processes

# Processing pipeline
process:
  - whitespace_normalization_mapper: {}
  - language_id_score_filter:
      lang: 'en'
      min_score: 0.8
  - text_length_filter:
      min_len: 10
      max_len: 200
  - document_deduplicator:
      lowercase: true
"""

# Write recipe to file
os.makedirs('configs', exist_ok=True)
with open('configs/basic_recipe.yaml', 'w') as f:
    f.write(recipe_content)

print("Recipe created at configs/basic_recipe.yaml")
print("Recipe content:")
print(recipe_content)
# Out:
# Recipe created at configs/basic_recipe.yaml
# Recipe content:
#
# project_name: 'getting_started_tutorial'
# dataset_path: './data/sample_dataset.jsonl'
# export_path: './outputs/processed_dataset.jsonl'
# np: 1  # Number of processes
#
# # Processing pipeline
# process:
#   - whitespace_normalization_mapper: {}
#   - language_id_score_filter:
#       lang: 'en'
#       min_score: 0.8
#   - text_length_filter:
#       min_len: 10
#       max_len: 200
#   - document_deduplicator:
#       lowercase: true

# %% [markdown]
# ## Running the Processing Pipeline
#
# Now let's run our data processing pipeline using the recipe we created.

# %%
# You can use command line tool
# !dj-process --config configs/basic_recipe.yaml
# or this way, only for installation from source and located in the root directory of data-juicer
# !python tools/process_data.py --config configs/basic_recipe.yaml
# Out:
# 2025-09-28 18:20:44.499 | INFO     | data_juicer.ops:timing_context:12 - Importing operator modules took 3.24 seconds
# 2025-09-28 18:20:45.862 | INFO     | data_juicer.config.config:660 - dataset_path config is set and a valid local path
# 2025-09-28 18:20:45.893 | INFO     | data_juicer.config.config:970 - Back up the input config file [/home/cmgzn/data-juicer/notebook/juicybook/configs/basic_recipe.yaml] into the work_dir [/home/cmgzn/data-juicer/notebook/juicybook/outputs]
# 2025-09-28 18:20:45.898 | INFO     | data_juicer.config.config:991 - Configuration table:
# ╒══════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                                                    │
# ╞══════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(configs/basic_recipe.yaml, cwd=/home/cmgzn/data-juicer/notebook/juicybook)]                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'getting_started_tutorial'                                                                                │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/home/cmgzn/data-juicer/notebook/juicybook/data/sample_dataset.jsonl'                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/home/cmgzn/data-juicer/notebook/juicybook/outputs'                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/home/cmgzn/data-juicer/notebook/juicybook/outputs/processed_dataset.jsonl'                              │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 1                                                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'text'                                                                                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                                                  │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                                                  │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                                                  │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/cmgzn/.cache/huggingface/datasets'                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                                                   │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'whitespace_normalization_mapper': {'accelerator': None,                                                │
# │                          │                                       'audio_key': 'audios',                                              │
# │                          │                                       'audio_special_token': '<__dj__audio>',                             │
# │                          │                                       'cpu_required': 1,                                                  │
# │                          │                                       'eoc_special_token': '<|__dj__eoc|>',                               │
# │                          │                                       'gpu_required': 0,                                                  │
# │                          │                                       'history_key': 'history',                                           │
# │                          │                                       'image_bytes_key': 'image_bytes',                                   │
# │                          │                                       'image_key': 'images',                                              │
# │                          │                                       'image_special_token': '<__dj__image>',                             │
# │                          │                                       'index_key': None,                                                  │
# │                          │                                       'instruction_key': 'instruction',                                   │
# │                          │                                       'mem_required': 0,                                                  │
# │                          │                                       'num_proc': 1,                                                      │
# │                          │                                       'prompt_key': 'prompt',                                             │
# │                          │                                       'query_key': 'query',                                               │
# │                          │                                       'response_key': 'response',                                         │
# │                          │                                       'skip_op_error': True,                                              │
# │                          │                                       'system_key': 'system',                                             │
# │                          │                                       'text_key': 'text',                                                 │
# │                          │                                       'turbo': False,                                                     │
# │                          │                                       'video_key': 'videos',                                              │
# │                          │                                       'video_special_token': '<__dj__video>',                             │
# │                          │                                       'work_dir': '/home/cmgzn/data-juicer/notebook/juicybook/outputs'}}, │
# │                          │  {'language_id_score_filter': {'accelerator': None,                                                       │
# │                          │                                'audio_key': 'audios',                                                     │
# │                          │                                'audio_special_token': '<__dj__audio>',                                    │
# │                          │                                'cpu_required': 1,                                                         │
# │                          │                                'eoc_special_token': '<|__dj__eoc|>',                                      │
# │                          │                                'gpu_required': 0,                                                         │
# │                          │                                'history_key': 'history',                                                  │
# │                          │                                'image_bytes_key': 'image_bytes',                                          │
# │                          │                                'image_key': 'images',                                                     │
# │                          │                                'image_special_token': '<__dj__image>',                                    │
# │                          │                                'index_key': None,                                                         │
# │                          │                                'instruction_key': 'instruction',                                          │
# │                          │                                'lang': 'en',                                                              │
# │                          │                                'max_closed_interval': True,                                               │
# │                          │                                'mem_required': 0,                                                         │
# │                          │                                'min_closed_interval': True,                                               │
# │                          │                                'min_score': 0.8,                                                          │
# │                          │                                'num_proc': 1,                                                             │
# │                          │                                'prompt_key': 'prompt',                                                    │
# │                          │                                'query_key': 'query',                                                      │
# │                          │                                'response_key': 'response',                                                │
# │                          │                                'reversed_range': False,                                                   │
# │                          │                                'skip_op_error': True,                                                     │
# │                          │                                'stats_export_path': None,                                                 │
# │                          │                                'system_key': 'system',                                                    │
# │                          │                                'text_key': 'text',                                                        │
# │                          │                                'turbo': False,                                                            │
# │                          │                                'video_key': 'videos',                                                     │
# │                          │                                'video_special_token': '<__dj__video>',                                    │
# │                          │                                'work_dir': '/home/cmgzn/data-juicer/notebook/juicybook/outputs'}},        │
# │                          │  {'text_length_filter': {'accelerator': None,                                                             │
# │                          │                          'audio_key': 'audios',                                                           │
# │                          │                          'audio_special_token': '<__dj__audio>',                                          │
# │                          │                          'cpu_required': 1,                                                               │
# │                          │                          'eoc_special_token': '<|__dj__eoc|>',                                            │
# │                          │                          'gpu_required': 0,                                                               │
# │                          │                          'history_key': 'history',                                                        │
# │                          │                          'image_bytes_key': 'image_bytes',                                                │
# │                          │                          'image_key': 'images',                                                           │
# │                          │                          'image_special_token': '<__dj__image>',                                          │
# │                          │                          'index_key': None,                                                               │
# │                          │                          'instruction_key': 'instruction',                                                │
# │                          │                          'max_closed_interval': True,                                                     │
# │                          │                          'max_len': 200,                                                                  │
# │                          │                          'mem_required': 0,                                                               │
# │                          │                          'min_closed_interval': True,                                                     │
# │                          │                          'min_len': 10,                                                                   │
# │                          │                          'num_proc': 1,                                                                   │
# │                          │                          'prompt_key': 'prompt',                                                          │
# │                          │                          'query_key': 'query',                                                            │
# │                          │                          'response_key': 'response',                                                      │
# │                          │                          'reversed_range': False,                                                         │
# │                          │                          'skip_op_error': True,                                                           │
# │                          │                          'stats_export_path': None,                                                       │
# │                          │                          'system_key': 'system',                                                          │
# │                          │                          'text_key': 'text',                                                              │
# │                          │                          'turbo': False,                                                                  │
# │                          │                          'video_key': 'videos',                                                           │
# │                          │                          'video_special_token': '<__dj__video>',                                          │
# │                          │                          'work_dir': '/home/cmgzn/data-juicer/notebook/juicybook/outputs'}},              │
# │                          │  {'document_deduplicator': {'accelerator': None,                                                          │
# │                          │                             'audio_key': 'audios',                                                        │
# │                          │                             'audio_special_token': '<__dj__audio>',                                       │
# │                          │                             'cpu_required': 1,                                                            │
# │                          │                             'eoc_special_token': '<|__dj__eoc|>',                                         │
# │                          │                             'gpu_required': 0,                                                            │
# │                          │                             'history_key': 'history',                                                     │
# │                          │                             'ignore_non_character': False,                                                │
# │                          │                             'image_bytes_key': 'image_bytes',                                             │
# │                          │                             'image_key': 'images',                                                        │
# │                          │                             'image_special_token': '<__dj__image>',                                       │
# │                          │                             'index_key': None,                                                            │
# │                          │                             'instruction_key': 'instruction',                                             │
# │                          │                             'lowercase': True,                                                            │
# │                          │                             'mem_required': 0,                                                            │
# │                          │                             'num_proc': 1,                                                                │
# │                          │                             'prompt_key': 'prompt',                                                       │
# │                          │                             'query_key': 'query',                                                         │
# │                          │                             'response_key': 'response',                                                   │
# │                          │                             'skip_op_error': True,                                                        │
# │                          │                             'system_key': 'system',                                                       │
# │                          │                             'text_key': 'text',                                                           │
# │                          │                             'turbo': False,                                                               │
# │                          │                             'video_key': 'videos',                                                        │
# │                          │                             'video_special_token': '<__dj__video>',                                       │
# │                          │                             'work_dir': '/home/cmgzn/data-juicer/notebook/juicybook/outputs'}}]           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                                                     │
# ╘══════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════╛
# 2025-09-28 18:20:45.901 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.12 seconds
# 2025-09-28 18:20:45.914 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2025-09-28 18:20:45.946 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2025-09-28 18:20:45.947 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2025-09-28 18:20:45.947 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /home/cmgzn/data-juicer/notebook/juicybook/data/sample_dataset.jsonl
# 2025-09-28 18:20:45.947 | INFO     | data_juicer.core.data.load_strategy:83 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2025-09-28 18:20:45.947 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2025-09-28 18:20:45.947 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.05 seconds
# 2025-09-28 18:20:45.948 | INFO     | data_juicer.core.executor.default_executor:115 - Loading dataset from dataset builder...
# Generating jsonl split: 5 examples [00:00, 3508.12 examples/s]
# 2025-09-28 18:20:46.863 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2025-09-28 18:20:46.863 | INFO     | data_juicer.format.formatter:191 - There are 5 sample(s) in the original dataset.
# Filter: 100%|##########| 5/5 [00:00<00:00, 1801.83 examples/s]
# 2025-09-28 18:20:46.870 | INFO     | data_juicer.format.formatter:203 - 5 samples left after filtering empty text.
# 2025-09-28 18:20:46.871 | INFO     | data_juicer.core.executor.default_executor:121 - Preparing process operators...
# 2025-09-28 18:20:46.872 | INFO     | data_juicer.utils.model_utils:413 - Loading fasttext language identification model...
# 2025-09-28 18:20:47.058 | INFO     | data_juicer.core.executor.default_executor:148 - Processing data...
# 2025-09-28 18:20:47.080 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[whitespace_normalization_mapper] based on the required memory: 0GB and required cpu: 1.
# whitespace_normalization_mapper_process: 100%|##########| 5/5 [00:00<00:00, 1057.73 examples/s]
# 2025-09-28 18:20:47.665 | INFO     | data_juicer.core.data.dj_dataset:306 - [1/4] OP [whitespace_normalization_mapper] Done in 0.607s. Left 5 samples.
# 2025-09-28 18:20:47.690 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[language_id_score_filter] based on the required memory: 0GB and required cpu: 1.
# Adding new column for stats: 100%|##########| 5/5 [00:00<00:00, 1168.92 examples/s]
# 2025-09-28 18:20:47.701 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[language_id_score_filter] based on the required memory: 0GB and required cpu: 1.
# language_id_score_filter_compute_stats:   0%|          | 0/5 [00:00<?, ? examples/s]2025-09-28 18:20:47.710 | INFO     | data_juicer.utils.model_utils:413 - Loading fasttext language identification model...
# language_id_score_filter_compute_stats: 100%|##########| 5/5 [00:00<00:00, 50.10 examples/s]
# 2025-09-28 18:20:47.810 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[language_id_score_filter] based on the required memory: 0GB and required cpu: 1.
# language_id_score_filter_process: 100%|##########| 5/5 [00:00<00:00, 2084.44 examples/s]
# 2025-09-28 18:20:48.268 | INFO     | data_juicer.core.data.dj_dataset:306 - [2/4] OP [language_id_score_filter] Done in 0.602s. Left 3 samples.
# 2025-09-28 18:20:48.287 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[text_length_filter] based on the required memory: 0GB and required cpu: 1.
# text_length_filter_compute_stats: 100%|##########| 3/3 [00:00<00:00, 486.95 examples/s]
# 2025-09-28 18:20:48.306 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[text_length_filter] based on the required memory: 0GB and required cpu: 1.
# text_length_filter_process: 100%|##########| 3/3 [00:00<00:00, 1150.91 examples/s]
# 2025-09-28 18:20:48.853 | INFO     | data_juicer.core.data.dj_dataset:306 - [3/4] OP [text_length_filter] Done in 0.585s. Left 3 samples.
# 2025-09-28 18:20:48.871 | INFO     | data_juicer.utils.process_utils:115 - Set the auto `num_proc` to 19 of Op[document_deduplicator] based on the required memory: 0GB and required cpu: 1.
# document_deduplicator_compute_hash: 100%|##########| 3/3 [00:00<00:00, 460.22 examples/s]
# Filter: 100%|##########| 3/3 [00:00<00:00, 1434.60 examples/s]
# 2025-09-28 18:20:49.443 | INFO     | data_juicer.core.data.dj_dataset:306 - [4/4] OP [document_deduplicator] Done in 0.589s. Left 2 samples.
# 2025-09-28 18:20:51.216 | INFO     | data_juicer.utils.logger_utils:257 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/home/cmgzn/data-juicer/notebook/juicybook/outputs/log/export_processed_dataset.jsonl_time_20250928182045.txt] and its related log files.
# 2025-09-28 18:20:51.216 | INFO     | data_juicer.core.executor.default_executor:160 - All OPs are done in 4.158s.
# 2025-09-28 18:20:51.216 | INFO     | data_juicer.core.executor.default_executor:164 - Exporting dataset to disk...
# 2025-09-28 18:20:51.217 | INFO     | data_juicer.core.exporter:104 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 1020.02ba/s]
# 2025-09-28 18:20:51.223 | INFO     | data_juicer.core.exporter:136 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 912.20ba/s]
# 2025-09-28 18:20:51.225 | INFO     | data_juicer.tools.process_data:15 - Running executor took 5.28 seconds

# %% [markdown]
# ## Inspecting the Results
#
# Let's examine what happened during processing:

# %%
# Let's look at the original data vs processed data

with open('outputs/processed_dataset.jsonl', 'r') as f:
    dataset = [json.loads(line) for line in f]

print("Original samples:")
for i, sample in enumerate(sample_data):
    print(f"{i+1}. {sample['text']}")

print("\nProcessed samples:")
for i, sample in enumerate(dataset):
    print(f"{i+1}. {sample['text']}")

print("\nWhat happened during processing?")
print("1. Whitespace normalization: Fixed spacing issues")
print("2. Language filtering: Kept only English texts (removed French)")
print("3. Length filtering: Removed texts that were too short")
print("4. Deduplication: Removed duplicate texts (case-insensitive)")
# Out:
# Original samples:
# 1. Hello world! This is a sample text with good quality.
# 2. hello world! this is a sample text with good quality.
# 3. a text
# 4. Bonjour le monde! Ceci est un texte d'exemple de bonne qualité.
# 5. Hello world! 	Hello world! This is a sample text with good quality. Hello world! This is a sample text with good quality.
#
# Processed samples:
# 1. Hello world! This is a sample text with good quality.
# 2. Hello world!  Hello world! This is a sample text with good quality. Hello world! This is a sample text with good quality.
#
# What happened during processing?
# 1. Whitespace normalization: Fixed spacing issues
# 2. Language filtering: Kept only English texts (removed French)
# 3. Length filtering: Removed texts that were too short
# 4. Deduplication: Removed duplicate texts (case-insensitive)

# %% [markdown]
# Finally, we remove the temporary files

# %%
import os
os.remove('configs/basic_recipe.yaml')
os.remove('data/sample_dataset.jsonl')

# %% [markdown]
# ## Next Steps
#
# Continue with the next notebook in the series to dive deeper into operators and their usage.
